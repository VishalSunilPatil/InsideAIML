# %% [markdown]
# # Create a Vehicle class with max_speed and mileage As  Data Members

# %%
class Vehicle:
    def __init__(self,max,mileage):
        self.max_speed = max
        self.mileage = mileage
veh = Vehicle("50","55KMPL")
print(veh.max_speed)
print(veh.mileage)
# Out:
# 50
# 55KMPL

# %% [markdown]
# # Create a Vehicle class without any variables and method

# %%
class Vehicle:
    pass

# %% [markdown]
# #  Create a child class Bus that will inherit all of the  variables and methods of the Vehicle class

# %%
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage
        self.color = "White"

class Car(Vehicle):
    pass

car = Car("Hyundai","120KMPH","20KMPL")
print("Vehicle Name:", car.name, " Speed:", car.max_speed, "Mileage:", car.mileage,"Color:", car.color)
# Out:
# Vehicle Name: Hyundai  Speed: 120KMPH Mileage: 20KMPL Color: White

# %% [markdown]
# #  Define property that should have the same value for  every class instance

# %%
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage
        self.color = "White"

car = Vehicle("Hyundai","120KMPH","20KMPL")
print("Vehicle Name:", car.name, " Speed:", car.max_speed, "Mileage:", car.mileage,"Color:", car.color)
bus = Vehicle("Volvo", "80KMPH", "12KMPL")
print("Vehicle Name:", bus.name, " Speed:", bus.max_speed, "Mileage:", bus.mileage,"Color:", bus.color)
# Out:
# Vehicle Name: Hyundai  Speed: 120KMPH Mileage: 20KMPL Color: White
# Vehicle Name: Volvo  Speed: 80KMPH Mileage: 12KMPL Color: White

# %% [markdown]
# # Create a Bus child class that inherits from the Vehicle class. The default fare charge  of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add  an extra 10% on full fare as a maintenance charge. So total fare for bus instance will  become the final amount = total fare + 10% of the total fare.
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You  need to override the fare() method of a Vehicle class in Bus class.
# Use the following code for your parent Vehicle class. We need to access the parent

# %%
class Vehicle:
    def __init__(self, name, mileage, capacity):
        self.name = name
        self.mileage = mileage
        self.capacity = capacity

    def fare(self):
        return self.capacity * 100

class Bus(Vehicle):
    def fare(self):
        finalamount = super().fare()
        finalamount = finalamount + (finalamount * 10 / 100)
        return finalamount

Veh = Bus("Volvo", 12, 50)
print("Total Bus fare :", Veh.fare())
# Out:
# Total Bus fare : 5500.0

# %% [markdown]
# # Determine which class a given Bus object belongs to  (Check type of an object)

# %%
class Vehicle:
    def __init__(self, name):
        self.name = name

class Car(Vehicle):
    pass

Polo = Car("School Volvo")
print(type(Polo))
# Out:
# <class '__main__.Car'>
